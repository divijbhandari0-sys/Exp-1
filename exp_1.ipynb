# %% [markdown]
# Exp 1 : Introduction to python,
# Name : Divij Bhandari 25070123160

# %%
x,y,z="apple","orange","cherry"
print(x,y,z,sep="\n")
# Out:
# apple
# orange
# cherry

# %%
x,y,z,w=2,2.5,"Divij",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("add=",a+b,"\nsub=",a-b,"\nmult=",a*b,"\ndiv=",a/b,"\nexp=",a**b,)
# Out:
# add= 15
# sub= 5
# mult= 50
# div= 2.0
# exp= 100000

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("add=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b,"\n",)
# Out:
# enter the value of a=2
# enter the value of b=3
# add= 5
#  sub= -1
#  mult= 6
#  div= 0.6666666666666666
#  exp= 8

# %%
import math

radius = float(input("Enter the radius of the circle: "))

area = math.pi * radius ** 2

print("The area of the circle is:", area)
# Out:
# Enter the radius of the circle: 4
# The area of the circle is: 50.26548245743669

# %%
import math

value=math.log10(10)
print(value)
# Out:
# 1.0

# %%
import math

value=math.sin(math.radians(60))
print(value)
# Out:
# 0.8660254037844386

# %%
a, b = 10, 5

if b < a:
    print("a is greater than b")
else:
    print("a is not less than b")
# Out:
# a is greater than b
